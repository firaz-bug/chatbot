# %% [markdown]
# <a href="https://colab.research.google.com/github/firaz-bug/chatbot/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import json
import pickle
import numpy as np
import os

import nltk
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.models import load_model

nltk.download('punkt', quiet=True)
nltk.download('wordnet', quiet=True)

lemmatizer = WordNetLemmatizer()

intents = json.loads(open("intents.json").read())

words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        word = nltk.word_tokenize(pattern)
        words.extend(word)
        documents.append((word, intent['tag']))
        if intent['tag'] not in classes:
        	classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

pickle.dump(words, open('words.pkl','wb'))
pickle.dump(classes, open('classes.pkl','wb'))

training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = []
    word_patterns = doc[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

random.shuffle(training)
training = np.array(training)

train_x = list(training[:, 0])
train_y = list(training[:, 1])

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('model_chatbot.model')
print("done!")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/200
# 4/4 [==============================] - 1s 3ms/step - loss: 1.8296 - accuracy: 0.2000
# Epoch 2/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7718 - accuracy: 0.4000
# Epoch 3/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7771 - accuracy: 0.2000
# Epoch 4/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6805 - accuracy: 0.3500
# Epoch 5/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6726 - accuracy: 0.4000
# Epoch 6/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7381 - accuracy: 0.2000
# Epoch 7/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6852 - accuracy: 0.3000
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6439 - accuracy: 0.3500
# Epoch 9/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6629 - accuracy: 0.3000
# Epoch 10/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5943 - accuracy: 0.3000
# Epoch 11/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3590 - accuracy: 0.6000
# Epoch 12/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3859 - accuracy: 0.5500
# Epoch 13/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2952 - accuracy: 0.7000
# Epoch 14/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2894 - accuracy: 0.6000
# Epoch 15/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2967 - accuracy: 0.5500
# Epoch 16/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3976 - accuracy: 0.4500
# Epoch 17/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2462 - accuracy: 0.6000
# Epoch 18/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1968 - accuracy: 0.5500
# Epoch 19/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0317 - accuracy: 0.7500
# Epoch 20/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9871 - accuracy: 0.6000
# Epoch 21/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8839 - accuracy: 0.8000
# Epoch 22/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9382 - accuracy: 0.6000
# Epoch 23/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9695 - accuracy: 0.6500
# Epoch 24/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8969 - accuracy: 0.7000
# Epoch 25/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7905 - accuracy: 0.8500
# Epoch 26/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8398 - accuracy: 0.8000
# Epoch 27/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7575 - accuracy: 0.8000
# Epoch 28/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6066 - accuracy: 0.7500
# Epoch 29/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6943 - accuracy: 0.8500
# Epoch 30/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6400 - accuracy: 0.7500
# Epoch 31/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4890 - accuracy: 0.8500
# Epoch 32/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5990 - accuracy: 0.8000
# Epoch 33/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4889 - accuracy: 1.0000
# Epoch 34/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5122 - accuracy: 0.8000
# Epoch 35/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4800 - accuracy: 0.8000
# Epoch 36/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6444 - accuracy: 0.8000
# Epoch 37/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6322 - accuracy: 0.8000
# Epoch 38/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5865 - accuracy: 0.8000
# Epoch 39/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2375 - accuracy: 1.0000
# Epoch 40/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2892 - accuracy: 1.0000
# Epoch 41/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3154 - accuracy: 0.9000
# Epoch 42/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3401 - accuracy: 0.9500
# Epoch 43/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5178 - accuracy: 0.7500
# Epoch 44/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3153 - accuracy: 1.0000
# Epoch 45/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3700 - accuracy: 0.9500
# Epoch 46/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1915 - accuracy: 0.9500
# Epoch 47/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2492 - accuracy: 0.9500
# Epoch 48/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1500 - accuracy: 0.9500
# Epoch 49/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2077 - accuracy: 0.9500
# Epoch 50/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2141 - accuracy: 0.9500
# Epoch 51/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1748 - accuracy: 0.9500
# Epoch 52/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1579 - accuracy: 0.9500
# Epoch 53/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3036 - accuracy: 0.9000
# Epoch 54/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1463 - accuracy: 1.0000
# Epoch 55/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1763 - accuracy: 1.0000
# Epoch 56/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1300 - accuracy: 1.0000
# Epoch 57/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0942 - accuracy: 1.0000
# Epoch 58/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1400 - accuracy: 1.0000
# Epoch 59/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2132 - accuracy: 0.9500
# Epoch 60/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0978 - accuracy: 1.0000
# Epoch 61/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2100 - accuracy: 0.9000
# Epoch 62/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1527 - accuracy: 0.9500
# Epoch 63/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1462 - accuracy: 1.0000
# Epoch 64/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1398 - accuracy: 1.0000
# Epoch 65/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2548 - accuracy: 0.9500
# Epoch 66/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1935 - accuracy: 0.9500
# Epoch 67/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1286 - accuracy: 1.0000
# Epoch 68/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1657 - accuracy: 1.0000
# Epoch 69/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 1.0000
# Epoch 70/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 71/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1871 - accuracy: 0.9000
# Epoch 72/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1970 - accuracy: 1.0000
# Epoch 73/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0860 - accuracy: 1.0000
# Epoch 74/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1102 - accuracy: 1.0000
# Epoch 75/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0506 - accuracy: 1.0000
# Epoch 76/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0926 - accuracy: 1.0000
# Epoch 77/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0879 - accuracy: 1.0000
# Epoch 78/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0997 - accuracy: 1.0000
# Epoch 79/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1262 - accuracy: 1.0000
# Epoch 80/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0875 - accuracy: 1.0000
# Epoch 81/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0471 - accuracy: 1.0000
# Epoch 82/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2065 - accuracy: 0.9000
# Epoch 83/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 84/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 85/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2375 - accuracy: 0.9500
# Epoch 86/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 87/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1458 - accuracy: 0.9500
# Epoch 88/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0668 - accuracy: 1.0000
# Epoch 89/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1920 - accuracy: 0.9000
# Epoch 90/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 91/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1858 - accuracy: 0.9500
# Epoch 92/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0996 - accuracy: 1.0000
# Epoch 93/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0586 - accuracy: 1.0000
# Epoch 94/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 1.0000
# Epoch 95/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0945 - accuracy: 1.0000
# Epoch 96/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1344 - accuracy: 0.9500
# Epoch 97/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 98/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0565 - accuracy: 1.0000
# Epoch 99/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 100/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0864 - accuracy: 1.0000
# Epoch 101/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 1.0000
# Epoch 102/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0436 - accuracy: 1.0000
# Epoch 103/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 104/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 0.9500
# Epoch 105/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 106/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1362 - accuracy: 0.9500
# Epoch 107/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1520 - accuracy: 0.9500
# Epoch 108/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0708 - accuracy: 0.9500
# Epoch 109/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0768 - accuracy: 1.0000
# Epoch 110/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0975 - accuracy: 0.9500
# Epoch 111/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0509 - accuracy: 1.0000
# Epoch 112/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 113/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1041 - accuracy: 1.0000
# Epoch 114/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 115/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0636 - accuracy: 1.0000
# Epoch 116/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1137 - accuracy: 0.9500
# Epoch 117/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 118/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 119/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 120/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 121/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0863 - accuracy: 1.0000
# Epoch 122/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1069 - accuracy: 0.9500
# Epoch 123/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 124/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 125/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 126/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 127/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1358 - accuracy: 0.9500
# Epoch 128/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 129/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 130/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0674 - accuracy: 1.0000
# Epoch 131/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 132/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 133/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 134/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 135/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1535 - accuracy: 0.9500
# Epoch 136/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0623 - accuracy: 0.9500
# Epoch 137/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0733 - accuracy: 1.0000
# Epoch 138/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 139/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 140/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0862 - accuracy: 1.0000
# Epoch 141/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1833 - accuracy: 0.9000
# Epoch 142/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 143/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0695 - accuracy: 1.0000
# Epoch 144/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 1.0000
# Epoch 145/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0724 - accuracy: 1.0000
# Epoch 146/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9500
# Epoch 147/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 148/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 149/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0482 - accuracy: 1.0000
# Epoch 150/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 151/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 152/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 1.0000
# Epoch 153/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 154/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 155/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 156/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 157/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0767 - accuracy: 1.0000
# Epoch 158/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 159/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1559 - accuracy: 0.9500
# Epoch 160/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 1.0000
# Epoch 161/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 162/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0813 - accuracy: 1.0000
# Epoch 163/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 164/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0727 - accuracy: 1.0000
# Epoch 165/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 166/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 167/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 168/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 169/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 170/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 171/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 172/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 173/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 174/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 175/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 176/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0878 - accuracy: 1.0000
# Epoch 177/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 178/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9500
# Epoch 179/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 180/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 181/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 182/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 183/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 184/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1590 - accuracy: 0.9500
# Epoch 185/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1377 - accuracy: 0.9500
# Epoch 186/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 0.9500
# Epoch 187/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0492 - accuracy: 1.0000
# Epoch 188/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 189/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9500
# Epoch 190/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 191/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 1.0000
# Epoch 192/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0451 - accuracy: 0.9500
# Epoch 193/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 194/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 195/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0754 - accuracy: 1.0000
# Epoch 196/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0312 - accuracy: 1.0000
# Epoch 197/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 198/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 199/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 200/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 1.0000
# INFO:tensorflow:Assets written to: model_chatbot.model/assets
# done!

# %%
import random
import json
import pickle
import numpy as np
import os

import nltk
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import load_model

lemmatizer = WordNetLemmatizer()

intents = json.loads(open("intents.json").read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('model_chatbot.model')

def _clean_up_sentence(sentence):
	sentence_words = nltk.word_tokenize(sentence)
	sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
	return sentence_words

def _bag_of_words(sentence, words):
    sentence_words = _clean_up_sentence(sentence)
    bag = [0] * len(words)
    for s in sentence_words:
        for i, word in enumerate(words):
            if word == s:
                bag[i] = 1
    return np.array(bag)

def _predict_class(sentence):
    p = _bag_of_words(sentence, words)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.1
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]

    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({'intent':classes[r[0]], 'probability': str(r[1])})
    return return_list

def _get_response(ints, intents_json):
    try:
        tag = ints[0]['intent']
        list_of_intents = intents_json['intents']
        for i in list_of_intents:
            if i['tag']  == tag:
                result = random.choice(i['responses'])
                break
    except IndexError:
        result = "I don't understand!"
    return result



print("BOT is up and running!")

while True:
  message = input("me:")
  if (message.lower()=="quit"):
    break
  ints = _predict_class(message)
  res = _get_response(ints,intents)
  print(res)
# Out:
# BOT is up and running!
# me:quit
